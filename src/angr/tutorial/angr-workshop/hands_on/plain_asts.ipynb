# %%
# Claripy is the abstraction layer of angr for ASTs
import claripy

# This function renders the AST as a nice graph ( if you have graphviz)
from angrcli.ast.rendering import render_ast

# Give the BitVector type a function to render to svg which Jupyter recognizes and uses for rendering
from claripy.ast.bv import BV
BV._repr_svg_ = lambda self: render_ast(self)._repr_svg_()

# %%
# Setup some variables
x = claripy.BVS('x', 32)
y = claripy.BVS('y', 32)

# %%
x
# Out:
# <BV32 x_0_32>

# %%
x + y
# Out:
# <BV32 x_0_32 + y_1_32>

# %%
# Trivial simplifications happen automatically
x - x + x
# Out:
# <BV32 x_0_32>

# %%
x + x + y
# Out:
# <BV32 __add__(x_0_32, x_0_32, y_1_32)>

# %%
(2 * x) + y
# Out:
# <BV32 (0x2 * x_0_32) + y_1_32>

# %%
x % 2
# Out:
# <BV32 x_0_32 % 0x2>
